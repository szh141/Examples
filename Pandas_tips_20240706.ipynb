# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/Examples/blob/main/Pandas_tips_20240706.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://medium.com/@matthewghannoum/pandas-basics-everything-you-need-to-know-for-90-of-your-projects-972a964a1377

# %%
import pandas as pd
people_df = pd.read_csv('/content/drive/MyDrive/Colab images/Data/people.csv')

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   personId:ID(Person-ID)  1000 non-null   object
#  1   first_name              1000 non-null   object
#  2   last_name               1000 non-null   object
#  3   birth_date:date         1000 non-null   object
#  4   age:int                 1000 non-null   int64
#  5   location                1000 non-null   object
#  6   genre                   1000 non-null   object
#  7   bot_score:float         1000 non-null   float64
#  8   :LABEL                  1000 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 70.4+ KB

# %%
people_df.head()
# Out:
#                  personId:ID(Person-ID) first_name last_name birth_date:date  \
# 0  4c419279-d0d6-4290-9563-b42db18dbe9b       Mark    Fields      1981-11-05
# 1  a7d0de70-bd31-45df-8df5-189966f1fe2e  Christine    Murphy      2005-03-12
# 2  62b2066b-5fbb-44b3-8899-0aa44f528ff8    Theresa      Frye      2012-02-21
# 3  9bef669c-7e66-4d86-bb82-ad3be9ac7c31   Jennifer      Rice      2007-03-27
# 4  e2aed787-255e-463b-a4a0-b1944ee8c706      Sarah  Anderson      1925-10-31
#
#    age:int                      location                          genre  \
# 0       43  Brentwood Estates Chicago US                          Music
# 1       19        Kensington New York US                     Technology
# 2       12             Keene New York US                     Technology
# 3       17             Murray Chicago US  Business and entrepreneurship
# 4       99    Palm Desert Los Angeles US                    Photography
#
#    bot_score:float  :LABEL
# 0             0.12  person
# ...

# %%
# read certain columns
people_df = pd.read_csv("/content/drive/MyDrive/Colab images/Data/people.csv", usecols=["first_name", "last_name"])
people_df[10:20] # will display rows 10 to 19
# Out:
#    first_name last_name
# 10      Brian   Schultz
# 11        Amy   Wilkins
# 12      Laura  Williams
# 13    Anthony      Ryan
# 14     Daniel     Davis
# 15    Candice     Hardy
# 16      David    Gordon
# 17    Timothy       May
# 18       Anna   Herrera
# 19      James   Swanson

# %%
list_df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]], columns=["a", "b", "c"])
list_df # typing a variable name in a cell will display it's contents if in a Jupyter notebook
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
dict_df = pd.DataFrame({"a": [1, 2, 3], "b": [4, 5, 6], "c": [7, 8, 9]})
dict_df # typing a variable name in a cell will display it's contents if in a Jupyter notebook
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %% [markdown]
# ![Screenshot 2024-07-06 at 3.40.26 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-07-06 at 3.41.06 PM.png](data:image/png;base64,...)

# %%
people1_df = people_df[["first_name", "last_name", "genre"]][:500] # first 500 people
people2_df = people_df[["first_name", "last_name", "genre"]][500:] # last 500 people
people1_df
# Out:
#     first_name  last_name                          genre
# 0         Mark     Fields                          Music
# 1    Christine     Murphy                     Technology
# 2      Theresa       Frye                     Technology
# 3     Jennifer       Rice  Business and entrepreneurship
# 4        Sarah   Anderson                    Photography
# ..         ...        ...                            ...
# 495      Amber     Jacobs                        Fitness
# 496    Allison      Chase                        Fashion
# 497      Susan    Griffin                        Cooking
# 498     Manuel  Fernandez                        Fashion
# 499  Elizabeth     Miller                          Books
#
# [500 rows x 3 columns]

# %%
people1_df.merge(people2_df, how="inner", left_on="genre", right_on="genre")
people1_df
# Out:
#     first_name  last_name                          genre
# 0         Mark     Fields                          Music
# 1    Christine     Murphy                     Technology
# 2      Theresa       Frye                     Technology
# 3     Jennifer       Rice  Business and entrepreneurship
# 4        Sarah   Anderson                    Photography
# ..         ...        ...                            ...
# 495      Amber     Jacobs                        Fitness
# 496    Allison      Chase                        Fashion
# 497      Susan    Griffin                        Cooking
# 498     Manuel  Fernandez                        Fashion
# 499  Elizabeth     Miller                          Books
#
# [500 rows x 3 columns]

# %%
# Conditional Filtering

# displays all people with a bot score between 0.5 and 0.75
people_df[(people_df["bot_score"] >= 0.5) & (people_df["bot_score"] <= 0.75)]
# displays all people with the first name Mark
people_df[people_df["first_name"] == "Mark"]
# displays all people with the first name Mark or John
people_df[people_df["first_name"].isin(["Mark", "John"])]
# displays all people who don't have the name Mark or John
# the not condition is done using the ~ symbol
people_df[~people_df["first_name"].isin(["Mark", "John"])]
