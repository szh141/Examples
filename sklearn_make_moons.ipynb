# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/Examples/blob/main/sklearn_make_moons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=(1000,50), noise=0.1, random_state=42)

plt.figure(figsize=(10, 5))
plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

for noise in [0,0.1,1]:
  X, y = make_moons(n_samples=1000, noise=noise, random_state=42)

  plt.figure(figsize=(10, 5))
  plt.scatter(X[:,0], X[:,1], c=y, cmap='RdBu', lw=0)
  plt.show()
