# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/Examples/blob/main/plot_gaussian_20250119.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://medium.com/data-bistrot/uniform-and-normal-statistical-distribution-in-python-6d07fd5fc552

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
mu = 0      # Mean
sigma = 1   # Standard deviation

# Generate data
data = np.random.normal(mu, sigma, 1000)

# Plot the histogram of the data
plt.hist(data, bins=30, density=True, alpha=0.6, color='b', edgecolor='black')

# Plot the theoretical PDF
x = np.linspace(-4, 4, 1000)
pdf = norm.pdf(x, mu, sigma)
plt.plot(x, pdf, 'r-', linewidth=2)

# Add titles and labels
plt.title('Normal Distribution (Mean=0, Std Dev=1)')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.show()

# %%
mu = 10  # 0
sigma = 2  # 1

# Generate data
data = np.random.normal(mu, sigma, 1000)

# Plot the histogram of the data
plt.hist(data, bins=30, density=True, alpha=0.6, color='b', edgecolor='black')

# Plot the theoretical PDF
x = np.linspace(2, 18, 1000). # (-4,4) --> (-8,8) x2 --> (2,18) shift 10
pdf = norm.pdf(x, mu, sigma)
plt.plot(x, pdf, 'r-', linewidth=2)

# Add titles and labels
plt.title('Normal Distribution (Mean=0, Std Dev=1)')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ![Screenshot 2025-01-19 at 9.42.38 AM.png](data:image/png;base64,...)

# %%
mu = 0      # Mean
sigma = 1   # Standard deviation

# Generate data
data = np.random.normal(mu, sigma, 1000)

# Plot the histogram of the data
plt.hist(data, bins=30, density=True, alpha=0.6, color='b', edgecolor='black')

# Plot the theoretical PDF
x = np.linspace(-4, 4, 1000)

# define gaussian instead of using scipy formula
a = 1/np.sqrt(2*np.pi*sigma**2)
b = -(x-mu)**2/(2*sigma**2)
pdf = a*np.exp(b)
plt.plot(x, pdf, 'r-', linewidth=2)

# Add titles and labels
plt.title('Normal Distribution (Mean=0, Std Dev=1)')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.show()
