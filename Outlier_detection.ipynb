# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/Examples/blob/main/Outlier_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://medium.com/@Coursesteach/supervised-learning-with-scikit-learn-part-11-removing-outliers-with-scikit-learn-59d6a2051d02
#
# Dummy data
# https://github.com/YBI-Foundation/Dataset/blob/main/Placement.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('/content/Placement.csv')
df.head()
# Out:
#    Student_ID  CGPA   IQ  Placement
# 0           1   6.8  123          1
# 1           2   5.9  106          0
# 2           3   5.3  121          0
# 3           4   7.4  132          1
# 4           5   5.8  142          0

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.distplot(df['CGPA'])
plt.subplot(1,2,2)
sns.distplot(df['IQ'])
# Out:
# <Axes: xlabel='IQ', ylabel='Density'>

# %%
print('Mean value of CGPA {}'.format(df['CGPA'].mean()))
print('Min value of CGPA {}'.format(df['CGPA'].min()))
print('Max value of CGPA {}'.format(df['CGPA'].max()))
print('Standard deviation value of CGPA {}'.format(round(df['CGPA'].std(),2)))
# Out:
# Mean value of CGPA 5.9910000000000005
# Min value of CGPA 3.3
# Max value of CGPA 8.5
# Standard deviation value of CGPA 1.14

# %%
# the boundary values are:
print('Highest value of CGPA', round(df['CGPA'].mean()+3*df['CGPA'].std(),3))
print('Lowest value of CGPA', round(df['CGPA'].mean()-3*df['CGPA'].std(),3))
# Out:
# Highest value of CGPA 9.422
# Lowest value of CGPA 2.56

# %%
df[(df['CGPA']<2.56)|(df['CGPA']>9.422)]
# Out:
# Empty DataFrame
# Columns: [Student_ID, CGPA, IQ, Placement]
# Index: []
