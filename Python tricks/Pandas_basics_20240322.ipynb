# %% [markdown]
# <a href="https://colab.research.google.com/github/szh141/Examples/blob/main/Python%20tricks/Pandas_basics_20240322.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

#series in pandas
s = pd.Series([3, -5, 7, 4], index = ['a','b','c','d'])
s
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64

# %%
#Dataframe in pandas
data = {'Country':['Belgium','India','Brazil'],
        'Capital':['Brussels','New Delhi','Brasilia'],
        'Population':['111907','1303021','208476']}

df = pd.DataFrame(data, columns = ['Country','Capital','Population'])
df
# Out:
#    Country    Capital Population
# 0  Belgium   Brussels     111907
# 1    India  New Delhi    1303021
# 2   Brazil   Brasilia     208476

# %%
s_1 = s.drop(['a','c'], axis=0)  # square bracket [] for more than one index or columns
s_1 # or s (inplace=True)
# Out:
# b   -5
# d    4
# dtype: int64

# %%
df_1 = df.drop('Country', axis = 1)
df_1
# Out:
#      Capital Population
# 0   Brussels     111907
# 1  New Delhi    1303021
# 2   Brasilia     208476

# %%
print(df.shape)
print(df.index)
print(df.columns)
# Out:
# (3, 3)
# RangeIndex(start=0, stop=3, step=1)
# Index(['Country', 'Capital', 'Population'], dtype='object')
